# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f572d396fae9> in <module>
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
a="hello"

# %%
a
# Out:
# 'hello'

# %%
import pandas as pd

# %%
df=pd.read_csv(r"Z:\Ck\ML\csv\numericalData.csv",usecols=["id","math"]);
df
# Out:
#     id  math
# 0   45    75
# 1  108    48
# 2   15    59
# 3   67    42
# 4  153    63
# 5   51    41
# 6  164    52

# %%
df.tail(2)
# Out:
#     id  math
# 5   51    41
# 6  164    52

# %%
df.head(3)
# Out:
#     id  math
# 5   51    41
# 6  164    52

# %%
df.shape
# Out:
# (2, 2)

# %%
df[['id','math']].sort_values('id',ascending=False)
# Out:
#     id  math
# 6  164    52
# 5   51    41

# %%
df.head
# Out:
# <bound method NDFrame.head of     id  math
# 5   51    41
# 6  164    52>

# %%
df.head(5)
# Out:
#     id  math
# 0   45    75
# 1  108    48
# 2   15    59
# 3   67    42
# 4  153    63

# %%
df[['id','math']].sort_values('id',ascending=False)
# Out:
#     id  math
# 6  164    52
# 4  153    63
# 1  108    48
# 3   67    42
# 5   51    41
# 0   45    75
# 2   15    59

# %%
df=pd.read_csv(r"Z:\Ck\ML\csv\numericalData.csv");
df
# Out:
#     id    45  program  math
# 0   45  12.0     45.0   NaN
# 1  108  78.0     59.0  48.0
# 2   15   NaN     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      NaN  41.0
# 6  164  45.0     78.0   NaN

# %%
df[['id','math']].sort_values('id',ascending=True)
# Out:
#     id  math
# 2   15    59
# 0   45    75
# 5   51    41
# 3   67    42
# 1  108    48
# 4  153    63
# 6  164    52

# %%
import numpy as np

# %%
df['profit_']=np.where(df['id']<100,True,False)
df
# Out:
#     id    45  program  math  profit_
# 0   45  12.0     45.0   NaN     True
# 1  108  78.0     59.0  48.0    False
# 2   15   NaN     86.0  59.0     True
# 3   67  49.0     12.0  42.0     True
# 4  153  19.0     45.0  63.0    False
# 5   51  46.0      NaN  41.0     True
# 6  164  45.0     78.0   NaN    False

# %%
df=pd.read_csv(r"Z:\Ck\ML\csv\numericalData.csv");
df
# Out:
#     id    45  program  math
# 0   45  12.0     45.0   NaN
# 1  108  78.0     59.0  48.0
# 2   15   NaN     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      NaN  41.0
# 6  164  45.0     78.0   NaN

# %%
newDf=df.dropna()
newDf
# Out:
#     id    45  program  math
# 1  108  78.0     59.0  48.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0

# %%
df.fillna(0)
# Out:
#     id    45  program  math
# 0   45  12.0     45.0   0.0
# 1  108  78.0     59.0  48.0
# 2   15   0.0     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      0.0  41.0
# 6  164  45.0     78.0   0.0

# %%
value={'id':0,'45':1,'program':2,'math':3}
df.fillna(value)
# Out:
#     id    45  program  math
# 0   45  12.0     45.0   3.0
# 1  108  78.0     59.0  48.0
# 2   15   1.0     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      2.0  41.0
# 6  164  45.0     78.0   3.0

# %%
m=round(df['math'].mean(),2)
m
# Out:
# 50.6

# %%
newDf1=df.fillna(m)
newDf1
# Out:
#     id    45  program  math
# 0   45  12.0     45.0  50.6
# 1  108  78.0     59.0  48.0
# 2   15  50.6     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0     50.6  41.0
# 6  164  45.0     78.0  50.6

# %%
value={'id':0,'45':1,'program':2,'math':m}
newDf1=df.fillna(value)
newDf1
# Out:
#     id    45  program  math
# 0   45  12.0     45.0  50.6
# 1  108  78.0     59.0  48.0
# 2   15   1.0     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      2.0  41.0
# 6  164  45.0     78.0  50.6

# %%
value={'id':0,'45':1,'program':2,'math':m}
newDf1=df.fillna(value)
newDf1
# Out:
#     id    45  program  math
# 0   45  12.0     45.0  41.0
# 1  108  78.0     59.0  48.0
# 2   15   1.0     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      2.0  41.0
# 6  164  45.0     78.0   NaN

# %%
m=round(df['math'].mode(),2)
m
# Out:
# 0    41.0
# 1    42.0
# 2    48.0
# 3    59.0
# 4    63.0
# dtype: float64

# %%
value={'id':0,'45':1,'program':2,'math':m}
newDf1=df.fillna(value)
newDf1
# Out:
#     id    45  program  math
# 0   45  12.0     45.0  41.0
# 1  108  78.0     59.0  48.0
# 2   15   1.0     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      2.0  41.0
# 6  164  45.0     78.0   NaN

# %%
m=round(df['math'].median(),2)
m
# Out:
# 48.0

# %%
value={'id':0,'45':1,'program':2,'math':m}
newDf1=df.fillna(value)
newDf1
# Out:
#     id    45  program  math
# 0   45  12.0     45.0  48.0
# 1  108  78.0     59.0  48.0
# 2   15   1.0     86.0  59.0
# 3   67  49.0     12.0  42.0
# 4  153  19.0     45.0  63.0
# 5   51  46.0      2.0  41.0
# 6  164  45.0     78.0  48.0

# %%
df['profit_']=np.where(['id']<['45'],50,100)
df
# Out:
#     id    45  program  math  profit_
# 0   45  12.0     45.0   NaN      100
# 1  108  78.0     59.0  48.0      100
# 2   15   NaN     86.0  59.0      100
# 3   67  49.0     12.0  42.0      100
# 4  153  19.0     45.0  63.0      100
# 5   51  46.0      NaN  41.0      100
# 6  164  45.0     78.0   NaN      100
