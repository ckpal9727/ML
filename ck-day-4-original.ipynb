# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
networkData=pd.read_csv(r"Z:\Ck\ML\csv\Network_data.csv")
networkData
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
networkData.head(10000)
# Out:
#            id                                               name   host_id  \
# 0        2539                 Clean & quiet apt home by the park      2787
# 1        2595                              Skylit Midtown Castle      2845
# 2        3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3        3831                    Cozy Entire Floor of Brownstone      4869
# 4        5022   Entire Apt: Spacious Studio/Loft by central park      7192
# 5        5099          Large Cozy 1 BR Apartment In Midtown East      7322
# 6        5121                                    BlissArtsSpace!      7356
# 7        5178                   Large Furnished Room Near B'way       8967
# 8        5203                 Cozy Clean Guest Room - Family Apt      7490
# 9        5238                 Cute & Cozy Lower East Side 1 bdrm      7549
# 10       5295                   Beautiful 1br on Upper West Side      7702
# ...

# %%
id_and_availability=networkData[['host_id','availability_365']].head(10)

# %%
id_and_availability
# Out:
#    host_id  availability_365
# 0     2787               365
# 1     2845               355
# 2     4632               365
# 3     4869               194
# 4     7192                 0
# 5     7322               129
# 6     7356                 0
# 7     8967               220
# 8     7490                 0
# 9     7549               188

# %%
data=id_and_availability.plot.area()

# %%
data=id_and_availability.plot.bar(x='host_id',y='availability_365')

# %%
data=id_and_availability.plot.line()

# %%
data=id_and_availability.plot.line(subplots=True)

# %%
data=id_and_availability.plot.scatter(x='host_id',y='availability_365')

# %%
data=id_and_availability.plot.pie(y='availability_365',figsize=(10,10))
